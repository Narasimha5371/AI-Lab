# %%
import numpy as np
a=np.array([12,4,56,7,29,10])
print("Original array:",a,"\nSorted array:",np.sort(a))
# Out:
# Original array: [12  4 56  7 29 10]
# Sorted array: [ 4  7 10 12 29 56]

# %%
b=np.array([[12,4,56],[7,29,10],[5,3,0]])
print(np.sort(b))
print(np.sort(b,axis=0))
# Out:
# [[ 4 12 56]
#  [ 7 10 29]
#  [ 0  3  5]]
# [[ 5  3  0]
#  [ 7  4 10]
#  [12 29 56]]

# %%
import pandas as pd
l=[10,20,30]
print(pd.Series(l))
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
dd={"Name":["Alice","Bob","Charlie","David"],"Age":[24,27,22,32],"Department":["HR","Finance","IT","Marketing"],
    "Salary":[50000,60000,55000,65000]}
d=pd.DataFrame(dd)
print(pd.DataFrame(d))
# Out:
#       Name  Age Department  Salary
# 0    Alice   24         HR   50000
# 1      Bob   27    Finance   60000
# 2  Charlie   22         IT   55000
# 3    David   32  Marketing   65000

# %%
print(d.loc[0])
# Out:
# Name          Alice
# Age              24
# Department       HR
# Salary        50000
# Name: 0, dtype: object

# %%
print(d.loc[0:2])
# Out:
#       Name  Age Department  Salary
# 0    Alice   24         HR   50000
# 1      Bob   27    Finance   60000
# 2  Charlie   22         IT   55000

# %%
print(d['Age'])
# Out:
# 0    24
# 1    27
# 2    22
# 3    32
# Name: Age, dtype: int64

# %%
print(d["Name"])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: object

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        4 non-null      object
#  1   Age         4 non-null      int64
#  2   Department  4 non-null      object
#  3   Salary      4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 260.0+ bytes

# %%
d.describe()
# Out:
#              Age        Salary
# count   4.000000      4.000000
# mean   26.250000  57500.000000
# std     4.349329   6454.972244
# min    22.000000  50000.000000
# 25%    23.500000  53750.000000
# 50%    25.500000  57500.000000
# 75%    28.250000  61250.000000
# max    32.000000  65000.000000

# %%
df
# Out:
#     Robot_ID   Task_Type Component_ID     Sensor_Type            Sensor_Data  \
# 0    RBT_001  Inspection      CMP_460           LIDAR  1 (obstacle detected)
# 1    RBT_002    Assembly      CMP_252         Thermal             85.3 (Â°C)
# 2    RBT_003  Inspection      CMP_248         Thermal       92% (visual fit)
# 3    RBT_004     Welding      CMP_433          Camera      98% (defect-free)
# 4    RBT_005    Assembly      CMP_992          Camera       92% (visual fit)
# ..       ...         ...          ...             ...                    ...
# 495  RBT_496  Inspection      CMP_834           LIDAR             85.3 (Â°C)
# 496  RBT_497  Inspection      CMP_851           LIDAR       92% (visual fit)
# 497  RBT_498  Inspection      CMP_657           LIDAR             82.4 (Â°C)
# 498  RBT_499    Assembly      CMP_562          Camera      98% (defect-free)
# 499  RBT_500    Assembly      CMP_465  LIDAR + Camera             75.8 (Â°C)
#
# ...

# %%
df=pd.read_excel("robot_dataset.xlsx")
df.head()
# Out:
#   Robot_ID   Task_Type Component_ID Sensor_Type            Sensor_Data  \
# 0  RBT_001  Inspection      CMP_460       LIDAR  1 (obstacle detected)
# 1  RBT_002    Assembly      CMP_252     Thermal             85.3 (Â°C)
# 2  RBT_003  Inspection      CMP_248     Thermal       92% (visual fit)
# 3  RBT_004     Welding      CMP_433      Camera      98% (defect-free)
# 4  RBT_005    Assembly      CMP_992      Camera       92% (visual fit)
#
#    Processing_Time (s)  Accuracy (%) Environmental_Status  \
# 0                 67.0          90.4               Stable
# 1                 71.2          98.1               Stable
# 2                 49.2          95.3             Unstable
# 3                 74.5          90.2               Stable
# 4                 64.5          97.2             Unstable
#
#    Energy_Consumption (kWh) Human_Intervention_Needed Obstacle_Detected  \
# 0                       2.2                        No               Yes
# ...

# %%
df.describe()
# Out:
#        Processing_Time (s)  Accuracy (%)  Energy_Consumption (kWh)
# count           500.000000    500.000000                500.000000
# mean             59.937000     94.920600                  2.014000
# std              11.688808      2.900949                  0.582789
# min              40.100000     90.000000                  1.000000
# 25%              49.675000     92.500000                  1.500000
# 50%              59.600000     94.900000                  2.000000
# 75%              70.000000     97.500000                  2.500000
# max              80.000000     99.900000                  3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Robot_ID                   500 non-null    object
#  1   Task_Type                  500 non-null    object
#  2   Component_ID               500 non-null    object
#  3   Sensor_Type                500 non-null    object
#  4   Sensor_Data                500 non-null    object
#  5   Processing_Time (s)        500 non-null    float64
#  6   Accuracy (%)               500 non-null    float64
#  7   Environmental_Status       500 non-null    object
#  8   Energy_Consumption (kWh)   500 non-null    float64
#  9   Human_Intervention_Needed  500 non-null    object
#  10  Obstacle_Detected          500 non-null    object
#  11  Defect_Detected            500 non-null    object
# dtypes: float64(3), object(9)
# memory usage: 47.0+ KB

# %%
df.loc[0:4]
# Out:
#   Robot_ID   Task_Type Component_ID Sensor_Type            Sensor_Data  \
# 0  RBT_001  Inspection      CMP_460       LIDAR  1 (obstacle detected)
# 1  RBT_002    Assembly      CMP_252     Thermal             85.3 (Â°C)
# 2  RBT_003  Inspection      CMP_248     Thermal       92% (visual fit)
# 3  RBT_004     Welding      CMP_433      Camera      98% (defect-free)
# 4  RBT_005    Assembly      CMP_992      Camera       92% (visual fit)
#
#    Processing_Time (s)  Accuracy (%) Environmental_Status  \
# 0                 67.0          90.4               Stable
# 1                 71.2          98.1               Stable
# 2                 49.2          95.3             Unstable
# 3                 74.5          90.2               Stable
# 4                 64.5          97.2             Unstable
#
#    Energy_Consumption (kWh) Human_Intervention_Needed Obstacle_Detected  \
# 0                       2.2                        No               Yes
# ...

# %%
df.tail()
# Out:
#     Robot_ID   Task_Type Component_ID     Sensor_Type        Sensor_Data  \
# 495  RBT_496  Inspection      CMP_834           LIDAR         85.3 (Â°C)
# 496  RBT_497  Inspection      CMP_851           LIDAR   92% (visual fit)
# 497  RBT_498  Inspection      CMP_657           LIDAR         82.4 (Â°C)
# 498  RBT_499    Assembly      CMP_562          Camera  98% (defect-free)
# 499  RBT_500    Assembly      CMP_465  LIDAR + Camera         75.8 (Â°C)
#
#      Processing_Time (s)  Accuracy (%) Environmental_Status  \
# 495                 66.3          96.2             Unstable
# 496                 45.1          92.8             Unstable
# 497                 75.4          98.7             Unstable
# 498                 48.7          94.9               Stable
# 499                 73.5          91.4               Stable
#
#      Energy_Consumption (kWh) Human_Intervention_Needed Obstacle_Detected  \
# 495                       1.3                        No               Yes
# ...

# %%
df["Robot_ID"]
# Out:
# 0      RBT_001
# 1      RBT_002
# 2      RBT_003
# 3      RBT_004
# 4      RBT_005
#         ...
# 495    RBT_496
# 496    RBT_497
# 497    RBT_498
# 498    RBT_499
# 499    RBT_500
# Name: Robot_ID, Length: 500, dtype: object

# %%
df.loc[212:237]
# Out:
#     Robot_ID   Task_Type Component_ID     Sensor_Type            Sensor_Data  \
# 212  RBT_213    Painting      CMP_622           LIDAR             82.4 (Â°C)
# 213  RBT_214  Inspection      CMP_215  LIDAR + Camera       92% (visual fit)
# 214  RBT_215    Painting      CMP_570           LIDAR         0 (clear path)
# 215  RBT_216     Welding      CMP_101         Thermal             85.3 (Â°C)
# 216  RBT_217     Welding      CMP_959           LIDAR             75.8 (Â°C)
# 217  RBT_218     Welding      CMP_226         Thermal  1 (obstacle detected)
# 218  RBT_219     Welding      CMP_193          Camera       92% (visual fit)
# 219  RBT_220    Assembly      CMP_167         Thermal  1 (obstacle detected)
# 220  RBT_221     Welding      CMP_725  LIDAR + Camera        0 (no obstacle)
# 221  RBT_222    Painting      CMP_506          Camera         0 (clear path)
# 222  RBT_223  Inspection      CMP_135  LIDAR + Camera             82.4 (Â°C)
# ...
